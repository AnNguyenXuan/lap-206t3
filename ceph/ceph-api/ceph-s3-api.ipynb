# %%
import sys
sys.executable
# Out:
# 'D:\\GitRepo\\lap-206t3\\ceph\\ceph-api\\venv\\Scripts\\python.exe'

# %%
# %pip install boto3 requests
# Out:
# Requirement already satisfied: boto3 in d:\gitrepo\lap-206t3\ceph\ceph-api\venv\lib\site-packages (1.42.29)
# Requirement already satisfied: requests in d:\gitrepo\lap-206t3\ceph\ceph-api\venv\lib\site-packages (2.32.5)
# Requirement already satisfied: botocore<1.43.0,>=1.42.29 in d:\gitrepo\lap-206t3\ceph\ceph-api\venv\lib\site-packages (from boto3) (1.42.29)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in d:\gitrepo\lap-206t3\ceph\ceph-api\venv\lib\site-packages (from boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in d:\gitrepo\lap-206t3\ceph\ceph-api\venv\lib\site-packages (from boto3) (0.16.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in d:\gitrepo\lap-206t3\ceph\ceph-api\venv\lib\site-packages (from botocore<1.43.0,>=1.42.29->boto3) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in d:\gitrepo\lap-206t3\ceph\ceph-api\venv\lib\site-packages (from botocore<1.43.0,>=1.42.29->boto3) (2.6.3)
# Requirement already satisfied: six>=1.5 in d:\gitrepo\lap-206t3\ceph\ceph-api\venv\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.43.0,>=1.42.29->boto3) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\gitrepo\lap-206t3\ceph\ceph-api\venv\lib\site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\gitrepo\lap-206t3\ceph\ceph-api\venv\lib\site-packages (from requests) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in d:\gitrepo\lap-206t3\ceph\ceph-api\venv\lib\site-packages (from requests) (2026.1.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import boto3
from botocore.client import Config

s3client = boto3.client(
    "s3",
    endpoint_url="https://gw01-s3.cloud360.vn",
    aws_access_key_id="AK",
    aws_secret_access_key="SK",
    config=Config(signature_version="s3"),
    region_name="us-east-1"
)

# %%
s3.list_objects_v2(Bucket="my-bucket")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 s3.list_objects_v2(Bucket="my-bucket")
#
# NameError: name 's3' is not defined
